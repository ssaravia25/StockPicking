# %% [markdown]
# # 📈 Trading Matrix Dashboard - Google Colab
#
# **Powered by Gradio** | Runs on Google Colab with free GPU/RAM
#
# ## 🚀 Quick Start Instructions
#
# 1. **Run Cell 1**: Install dependencies
# 2. **Run Cell 2**: Clone your repository
# 3. **Run Cell 3**: Launch the Gradio app
# 4. **Click the public link** that appears (valid for 72 hours)
#
# ---

# %% [markdown]
# ## Cell 1: Install Dependencies

# %%
# Install required packages
# !pip install -q gradio yfinance pandas numpy plotly scipy gspread gspread-formatting google-auth python-dotenv
print("✅ All packages installed!")

# %% [markdown]
# ## Cell 2: Clone Repository

# %%
import os

# Remove existing directory if present
if os.path.exists('StockPicking'):
    # !rm -rf StockPicking

# Clone your repository
# !git clone https://github.com/ssaravia25/StockPicking.git

# Change to repository directory
# %cd StockPicking

print("✅ Repository cloned and ready!")

# %% [markdown]
# ## Cell 3: Launch Gradio Dashboard
#
# **This will take 2-3 minutes on first run** (loading ~400 tickers with 2 years of data)
#
# After running, click the **public URL** (looks like: `https://xxxxx.gradio.live`)

# %%
# Launch the Gradio app
# !python gradio_app.py

# %% [markdown]
# ---
#
# ## 📝 Features Available
#
# ### 🚀 Live Market Scan
# - Scans all ~400 tickers for Stage 2 setups
# - Shows TOP Ideas (Quality Ranking > 85%)
# - Buy Alerts (Score < 4)
# - Full universe snapshot
#
# ### 📊 Performance Hub
# - Backtest results with 3 exit strategies
# - Equity curve vs SPY benchmark
# - Portfolio exposure chart
# - Current holdings
#
# ### 🔍 Ticker Deep Dive
# - Individual stock analysis
# - Price chart with entry/exit signals
# - Financial metrics
# - Theoretical trade log
#
# ---
#
# ## ⚡ Tips
#
# 1. **First load is slow** - Colab is downloading 2 years of data for ~400 stocks
# 2. **After first load** - Everything is cached and fast
# 3. **Public link expires in 72 hours** - Just re-run Cell 3 to get a new link
# 4. **Colab session timeout** - If idle for 90 minutes, re-run all cells
#
# ---
#
# ## 🔧 Troubleshooting
#
# **If you get errors:**
# 1. Go to **Runtime → Restart runtime**
# 2. Re-run all cells in order
#
# **If loading is too slow:**
# - Edit `src/ranking_backtest.py` line 16-18 to reduce ticker universe
# - Or use GPU runtime: **Runtime → Change runtime type → GPU**
#
# ---
#
# Made by **SFinance** | Not investment advice
